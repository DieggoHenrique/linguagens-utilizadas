# %% [markdown]
# ## Conhecendo a `requests`

# %% [markdown]
# ### Primeira requisição

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %% [markdown]
# ### Explorando a Biblioteca

# %%
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://api.github.com/events'

# %%
r.text
# Out:
# '[{"id":"50362346016","type":"IssueCommentEvent","actor":{"id":112244451,"login":"cowboymalboro1884","display_login":"cowboymalboro1884","gravatar_id":"","url":"https://api.github.com/users/cowboymalboro1884","avatar_url":"https://avatars.githubusercontent.com/u/112244451?"},"repo":{"id":993882573,"name":"cowboymalboro1884/rogue-n-roll","url":"https://api.github.com/repos/cowboymalboro1884/rogue-n-roll"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/cowboymalboro1884/rogue-n-roll/issues/2","repository_url":"https://api.github.com/repos/cowboymalboro1884/rogue-n-roll","labels_url":"https://api.github.com/repos/cowboymalboro1884/rogue-n-roll/issues/2/labels{/name}","comments_url":"https://api.github.com/repos/cowboymalboro1884/rogue-n-roll/issues/2/comments","events_url":"https://api.github.com/repos/cowboymalboro1884/rogue-n-roll/issues/2/events","html_url":"https://github.com/cowboymalboro1884/rogue-n-roll/pull/2","id":3105919707,"node_id":"PR_kwDOOz1xzc6
# ...

# %%
r.json()
# Out:
# [{'id': '50362346016',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 112244451,
#    'login': 'cowboymalboro1884',
#    'display_login': 'cowboymalboro1884',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cowboymalboro1884',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/112244451?'},
#   'repo': {'id': 993882573,
#    'name': 'cowboymalboro1884/rogue-n-roll',
#    'url': 'https://api.github.com/repos/cowboymalboro1884/rogue-n-roll'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/cowboymalboro1884/rogue-n-roll/issues/2',
#     'repository_url': 'https://api.github.com/repos/cowboymalboro1884/rogue-n-roll',
#     'labels_url': 'https://api.github.com/repos/cowboymalboro1884/rogue-n-roll/issues/2/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/cowboymalboro1884/rogue-n-roll/issues/2/comments',
# ...

# %%
r = requests.get('https://api.github.com/versions')
r.status_code
# Out:
# 200

# %%
# versão da api
r.json()
# Out:
# ['2022-11-28']

# %%
# especificando a versão da API
#headers = {'X-GitHub-Api-Version': '2022-11-28'}

# %%
import requests

r = requests.get('https://api.github.com/users/millenagena')
r
# Out:
# <Response [200]>

# %%
r.json()
# Out:
# {'login': 'millenagena',
#  'id': 69437878,
#  'node_id': 'MDQ6VXNlcjY5NDM3ODc4',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/69437878?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/millenagena',
#  'html_url': 'https://github.com/millenagena',
#  'followers_url': 'https://api.github.com/users/millenagena/followers',
#  'following_url': 'https://api.github.com/users/millenagena/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/millenagena/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/millenagena/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/millenagena/subscriptions',
#  'organizations_url': 'https://api.github.com/users/millenagena/orgs',
#  'repos_url': 'https://api.github.com/users/millenagena/repos',
#  'events_url': 'https://api.github.com/users/millenagena/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/millenagena/received_events',
# ...

# %% [markdown]
# ### Extraindo Dados

# %% [markdown]
# ## Obtendo dados dos Repositórios

# %%
# especificando a versão da API
headers = {'X-GitHub-Api-Version': '2022-11-28'}

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn' # username de quem vamos extrair os dados
url = f'{api_base_url}/users/{owner}/repos'

# %%
url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
response = requests.get(url, headers=headers)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# [{'id': 171339259,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#   'name': '.github',
#   'full_name': 'amzn/.github',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
# ...

# %%
len(response.json())
# Out:
# 30

# %% [markdown]
# ### Autenticação

# %%
access_token = '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' 
headers = {'Authorization' : 'Bearer' + access_token, 
           'X-GitHub-Api-Version': '2022-11-28'}

# %% [markdown]
# ### Pagianndo a url

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn' # username de quem vamos extrair os dados
url = f'{api_base_url}/users/{owner}/repos'
url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
repos_list = []
for page_num in range(1,6):
    try:
        url_page = f'{url}?page={page_num}'
        reponse = requests.get(url_page, headers=headers)
        repos_list.append(response.json())
    except:
        repos_list.append(None)

# %%
repos_list
# Out:
# [[{'id': 171339259,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#    'name': '.github',
#    'full_name': 'amzn/.github',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
# ...

# %%
len(repos_list)
# Out:
# 5

# %%
len(repos_list[0])
# Out:
# 30

# %% [markdown]
# ### Transformando os dados

# %%
repos_list[0][2]['name']
# Out:
# 'ads-pao-amznjs-gtm-server-side-template'

# %%
repos_name = []
for pages in repos_list:
    for repo in pages:
        repos_name.append(repo['name'])

# %%
repos_name[:10]
# Out:
# ['.github',
#  'ads-advanced-tools-docs',
#  'ads-pao-amznjs-gtm-server-side-template',
#  'ads-pao-amznjs-gtm-template',
#  'alexa-coho',
#  'alexa-skills-kit-js',
#  'amazon-ads-advertiser-audience-normalization-sdk-py',
#  'amazon-advertising-api-php-sdk',
#  'amazon-codeguru-profiler-for-spark',
#  'amazon-frustration-free-setup-certification-tool']

# %%
# Validação
len(repos_name)
# Out:
# 150

# %%
len(repos_list)
# Out:
# 5

# %% [markdown]
# ### LInguagens dos repositórios

# %%
repos_list[1][1]['language']
# Out:
# 'Jupyter Notebook'

# %%
repos_language = []
for page in repos_list:
    for repo in page:
        repos_language.append(repo['language'])

# %%
len(repos_language)
# Out:
# 150

# %%
repos_language
# Out:
# [None,
#  'Jupyter Notebook',
#  'Smarty',
#  'Smarty',
#  'JavaScript',
#  None,
#  'Python',
#  'PHP',
#  'Java',
#  'Python',
#  'CSS',
#  'Java',
#  'Java',
#  'PowerShell',
#  'Java',
#  'C#',
#  'PHP',
#  'Ruby',
#  'JavaScript',
#  'Python',
#  'PHP',
#  'Python',
#  'Jupyter Notebook',
#  'C#',
#  'Java',
#  'JavaScript',
#  'PHP',
#  'Ruby',
#  'PHP',
#  'C#',
#  None,
#  'Jupyter Notebook',
#  'Smarty',
#  'Smarty',
#  'JavaScript',
#  None,
#  'Python',
#  'PHP',
#  'Java',
#  'Python',
#  'CSS',
#  'Java',
#  'Java',
#  'PowerShell',
#  'Java',
#  'C#',
#  'PHP',
#  'Ruby',
#  'JavaScript',
#  'Python',
#  'PHP',
#  'Python',
#  'Jupyter Notebook',
#  'C#',
#  'Java',
#  'JavaScript',
#  'PHP',
#  'Ruby',
#  'PHP',
#  'C#',
#  None,
#  'Jupyter Notebook',
#  'Smarty',
#  'Smarty',
#  'JavaScript',
#  None,
#  'Python',
#  'PHP',
#  'Java',
#  'Python',
#  'CSS',
#  'Java',
#  'Java',
#  'PowerShell',
#  'Java',
#  'C#',
#  'PHP',
#  'Ruby',
#  'JavaScript',
#  'Python',
# ...

# %% [markdown]
# ### Criando um DataFrame

# %%
import pandas as pd

# %%
dados_amz = pd.DataFrame()
dados_amz['repository_name'] = repos_name
dados_amz['languages'] = repos_language

# %%
dados_amz
# Out:
#                              repository_name         languages
# 0                                    .github              None
# 1                    ads-advanced-tools-docs  Jupyter Notebook
# 2    ads-pao-amznjs-gtm-server-side-template            Smarty
# 3                ads-pao-amznjs-gtm-template            Smarty
# 4                                 alexa-coho        JavaScript
# ..                                       ...               ...
# 145                amazon-pay-api-sdk-nodejs        JavaScript
# 146                   amazon-pay-api-sdk-php               PHP
# 147                  amazon-pay-api-sdk-ruby              Ruby
# 148                  amazon-pay-code-samples               PHP
# 149                    amazon-pay-sdk-csharp                C#
#
# [150 rows x 2 columns]

# %% [markdown]
# ### Salvar em dataFrame

# %%
dados_amz.to_csv('amazon.csv')

# %% [markdown]
# # Armazenando os dados
#
# ### Criando repositórios com POST

# %%
api_base_url = 'https://api.github.com'
url = f'{api_base_url}/user/repos'

url
# Out:
# 'https://api.github.com/user/repos'

# %%
from requests.auth import HTTPBasicAuth
data = {
    'name' : 'linguagens-utilizadas',
    'description': 'Repositorio com as linguagens de prog da Amazon',
    'private': False
}

response = requests.post(url, json=data, auth=HTTPBasicAuth('dgghenri@gmail.com', ''))
response.status_code
# Out:
# 401

# %%
#Criação de um projeto no Github
import requests

url = 'https://api.github.com/user/repos'
token = 'token'

headers = {
    'Authorization': f'token {token}',
    'Accept': 'application/vnd.github.v3+json'
}

data = {
    'name': 'linguagens-utilizadas',
    'description': 'Repositorio com as linguagens de prog da Amazon',
    'private': False
}

response = requests.post(url, json=data, headers=headers)
print(response.status_code)
print(response.json())
# Out:
# 201
# ...

# %% [markdown]
# ### Formato de arquivo

# %%
import base64

# %% [markdown]
# [Documentação da API do GitHub]('https://docs.github.com/pt/rest/repos/contents?apiVersion=2022-11-28#create-or-update-file-contents')

# %%
with open('amazon.csv', 'rb') as file:
    file_content = file.read()
    
encoded_content = base64.b64encode(file_content)

# %%
api_base_url = 'https://api.github.com'
username = 'DieggoHenrique'
repo = 'linguagens-utilizadas'
path = 'amazon.csv'

url = f'{api_base_url}/repos/{username}/{repo}/contents/{path}'
url
# Out:
# 'https://api.github.com/repos/dieggohenrique/linguagens-utilizadas/contents/amazon.csv'

# %% [markdown]
# Assim como a requisição `POST`, a requisição `PUT` é um tipo de requisição `HTTP` (Hypertext Transfer Protocol) utilizada para enviar dados a um servidor. No entanto, a diferença entre elas está no tipo de operação que cada uma executa.
# Enquanto a requisição `POST` é utilizada para criar ou adicionar novos dados no servidor, a requisição `PUT` é utilizada para substituir completamente os dados de um recurso existente no servidor. Diferentemente do `PATCH`, que permite alterações parciais, o `PUT` realiza uma substituição completa dos dados.
#
# Assim como a requisição `POST`, a requisição `PUT` também envia os dados no corpo da mensagem da requisição. O envio desses dados segue um formato padrão, geralmente no formato `JSON` ou `XML`.
#
# Para fazer uma requisição `PUT` em Python, também é necessário utilizar a biblioteca `Requests` e enviar um dicionário com os dados que serão atualizados no corpo da mensagem. É possível também enviar outros parâmetros, como headers e cookies. É importante lembrar que nem todos os servidores aceitam a requisição `PUT` e, em alguns casos, é necessário ter permissão especial para fazer alterações.

# %%
data = {
    'message' : 'Adicionando um novo arquivo',
    'content' : encoded_content.decode('utf-8')
}

response = requests.put(url, json=data, headers=headers)
response.status_code
# Out:
# 201

# %% [markdown]
# [Forks - Create e `fork`]('https://docs.github.com/en/rest/repos/forks?apiVersion=2022-11-28#create-a-fork')
